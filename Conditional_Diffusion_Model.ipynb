# %% [markdown]
# <a href="https://colab.research.google.com/github/samuel23taku/NoteBooks/blob/main/Conditional_Diffusion_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from torchvision.transforms import  ToTensor, Normalize
import matplotlib.pyplot as plt
import os
from google.colab import drive
drive.mount('/content/drive')
os.popen("pip install diffusers")

transform= transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5, ))
])

training = datasets.MNIST(
    root="data",
    train=True,
    download=True,
    transform=transform
)

train_dataloader = DataLoader(
    training,batch_size=4500,shuffle=True
)

# %% [markdown]
# # Model

# %%
from diffusers import UNet2DModel
import  torch.nn as nn

class ClassConditionedUNet(nn.Module):
    def __init__(self, num_classes=10,class_emb_size=4):
        super().__init__()

        self.class_emb = nn.Embedding(num_classes, class_emb_size)

        self.model = UNet2DModel(
            sample_size=28,
            in_channels=1 + class_emb_size, #concat  the embedding to get new from the gray scale(1) channel
            out_channels=1,
            layers_per_block=2,
            block_out_channels=(32,64,64),
            down_block_types = (
            "DownBlock2D",
            "AttnDownBlock2D",
            "AttnDownBlock2D",
        ),

            up_block_types=(
                "UpBlock2D"
                "AttnUpBlock2D",
                "UpBlock2D"
                "AttnUpBlock2D",
                "UpBlock2D"
            )
        )

    def forward(self, x,t,class_labels):
        batch_size, channels, height, width = x.size()

        class_condition = self.class_emb(class_labels)
        class_condition = class_condition.view(batch_size, class_condition.shape[1], 1,1).expand(batch_size,class_condition.shape[1], width,height)

        net_input = torch.cat((x,class_condition),dim=1)
        return self.model(net_input,t).sample
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]

# %% [markdown]
# # Training

# %%
from diffusers import DDPMScheduler
from torch.optim import AdamW
from diffusers.optimization import get_cosine_schedule_with_warmup
from accelerate import Accelerator
from tqdm.auto import tqdm
import os
import shutil

noise_scheduler = DDPMScheduler(num_train_timesteps=1_000)

google_drive_weights_dir = '/content/drive/MyDrive/ConditionalDiffusionModelWeights'

def training_loop(epochs,model,noise_scheduler,training_dataloader):
    loss = nn.MSELoss()
    optimizer = AdamW(model.parameters(), lr=1e-4)
    # optimizer.load_state_dict(torch.load(f"{google_drive_weights_dir}/optimizer.pt"))
    lr_scheduler = get_cosine_schedule_with_warmup(optimizer=optimizer,num_warmup_steps=50,num_training_steps=(len(training_dataloader)*50))

    lr_scheduler.load_state_dict(torch.load(f"{google_drive_weights_dir}/scheduler.pt"))
    accelerator = Accelerator(
        mixed_precision="fp16",
        gradient_accumulation_steps=1
    )

    model ,optimizer, training_dataloader,lr_scheduler = accelerator.prepare(model,optimizer,training_dataloader,lr_scheduler)

    for epoch in range(0,epochs):
      progress_bar = tqdm(training_dataloader,desc=f"Epoch {epoch}/{epochs}")
      epoch_total_loss = 0.0

      for x, labels in progress_bar:
        x = x.to(accelerator.device)
        labels = labels.to(accelerator.device)

        noise = torch.randn_like(x)
        timesteps = torch.randint(0,99, (x.shape[0],)).long().to(accelerator.device)
        noised_images = noise_scheduler.add_noise(x, noise, timesteps)

        with accelerator.accumulate(model):
          noise_pred = model(noised_images,timesteps, labels)

          loss_error = loss(noise_pred, noise)
          accelerator.backward(loss_error)
          if accelerator.sync_gradients:
            accelerator.clip_grad_norm_(model.parameters(),1.0)
          optimizer.step()
          lr_scheduler.step()
          optimizer.zero_grad()


        epoch_total_loss += loss_error.detach().item()
        # logs = {"loss": loss_error.detach().item(), "lr": lr_scheduler.get_last_lr()[0], "Epoch": epoch+1 }

          # Saving weights

      if accelerator.is_main_process and epoch % 5 == 0:
        unwrapped_model = accelerator.unwrap_model(model)
        torch.save(unwrapped_model.state_dict(),f"{google_drive_weights_dir}/model_epoch({epoch})")

        torch.save(optimizer.state_dict(), f"{google_drive_weights_dir}/optimizer.pt")
        torch.save(lr_scheduler.state_dict(), f"{google_drive_weights_dir}/scheduler.pt")
        # save_weights_to_google_drive()
      print(f"Finished epoch-{epoch}  with average loss of :{epoch_total_loss}")
      epoch_average = epoch_total_loss / len(training_dataloader)
      progress_bar.set_postfix(loss=epoch_total_loss, lr=lr_scheduler.get_last_lr()[0])

    accelerator.end_training()



            # Save optimizer state
torch.cuda.empty_cache()
model = ClassConditionedUNet()
# model.load_state_dict(torch.load(f"{google_drive_weights_dir}/weights_375"))
training_loop(epochs=40,model=model,noise_scheduler=noise_scheduler,training_dataloader=train_dataloader)
# Out:
# <ipython-input-7-793ee232b4a8>:75: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"{google_drive_weights_dir}/weights_375"))
# <ipython-input-7-793ee232b4a8>:18: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   optimizer.load_state_dict(torch.load(f"{google_drive_weights_dir}/optimizer.pt"))
# <ipython-input-7-793ee232b4a8>:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   lr_scheduler.load_state_dict(torch.load(f"{google_drive_weights_dir}/scheduler.pt"))
# Epoch 1/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-0  with average loss of :3.188333978373607e-06
# Epoch 2/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-1  with average loss of :3.117178964874869e-06
# Epoch 3/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-2  with average loss of :3.1183385249835732e-06
# Epoch 4/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-3  with average loss of :3.1003360611945444e-06
# Epoch 5/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-4  with average loss of :3.15765751795176e-06
# Epoch 6/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-5  with average loss of :3.1659490795341452e-06
# Epoch 7/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-6  with average loss of :3.132070837248161e-06
# Epoch 8/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-7  with average loss of :3.146657402358553e-06
# Epoch 9/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-8  with average loss of :3.1512844220311444e-06
# Epoch 10/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-9  with average loss of :3.1132355035466605e-06
# Epoch 11/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-10  with average loss of :3.2823554796314974e-06
# Epoch 12/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-11  with average loss of :3.1759576962740364e-06
# Epoch 13/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-12  with average loss of :3.2980237867821783e-06
# Epoch 14/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-13  with average loss of :3.171057750945408e-06
# Epoch 15/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-14  with average loss of :3.16031908137778e-06
# Epoch 16/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-15  with average loss of :3.153653499953332e-06
# Epoch 17/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-16  with average loss of :3.136418851465667e-06
# Epoch 18/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-17  with average loss of :3.1359751318221884e-06
# Epoch 19/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-18  with average loss of :3.0170795524219412e-06
# Epoch 20/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-19  with average loss of :3.1419632888442525e-06
# Epoch 21/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-20  with average loss of :3.1241460310672985e-06
# Epoch 22/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-21  with average loss of :3.0747621803075778e-06
# Epoch 23/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-22  with average loss of :3.1059941550095224e-06
# Epoch 24/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-23  with average loss of :3.0233620319685802e-06
# Epoch 25/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-24  with average loss of :3.032290305961678e-06
# Epoch 26/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-25  with average loss of :3.066056652203361e-06
# Epoch 27/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-26  with average loss of :3.0359649627527137e-06
# Epoch 28/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-27  with average loss of :3.105844173866894e-06
# Epoch 29/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-28  with average loss of :3.0722646536267656e-06
# Epoch 30/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-29  with average loss of :3.051523375405623e-06
# Epoch 31/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-30  with average loss of :3.0524974570215773e-06
# Epoch 32/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-31  with average loss of :3.018822697707416e-06
# Epoch 33/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-32  with average loss of :3.1251868606240345e-06
# Epoch 34/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-33  with average loss of :3.0521596234237104e-06
# Epoch 35/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-34  with average loss of :3.1212460906892705e-06
# Epoch 36/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-35  with average loss of :3.1172951611200935e-06
# Epoch 37/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-36  with average loss of :3.3142542112112574e-06
# Epoch 38/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-37  with average loss of :3.2418778541146706e-06
# Epoch 39/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-38  with average loss of :3.2080943576162415e-06
# Epoch 40/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-39  with average loss of :3.0846136832717996e-06
# Epoch 41/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-40  with average loss of :3.1899273621910653e-06
# Epoch 42/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-41  with average loss of :3.2238873182271786e-06
# Epoch 43/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-42  with average loss of :3.127952611741749e-06
# Epoch 44/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-43  with average loss of :3.1358294652044324e-06
# Epoch 45/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-44  with average loss of :3.1450078227017716e-06
# Epoch 46/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-45  with average loss of :3.127452253231794e-06
# Epoch 47/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-46  with average loss of :3.0645677074770355e-06
# Epoch 48/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-47  with average loss of :3.078551068352912e-06
# Epoch 49/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-48  with average loss of :3.0530999433941727e-06
# Epoch 50/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-49  with average loss of :3.0921480443908043e-06
# Epoch 51/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-50  with average loss of :3.0725988744657575e-06
# Epoch 52/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-51  with average loss of :3.048533550239583e-06
# Epoch 53/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-52  with average loss of :3.120102482661094e-06
# Epoch 54/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-53  with average loss of :3.0050300367219958e-06
# Epoch 55/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-54  with average loss of :3.1221345404871376e-06
# Epoch 56/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-55  with average loss of :2.978757596426555e-06
# Epoch 57/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-56  with average loss of :3.0100860248765172e-06
# Epoch 58/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-57  with average loss of :3.0047197797603824e-06
# Epoch 59/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-58  with average loss of :3.047268478668754e-06
# Epoch 60/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-59  with average loss of :3.091459850621853e-06
# Epoch 61/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-60  with average loss of :2.986256764357938e-06
# Epoch 62/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-61  with average loss of :3.126013561206093e-06
# Epoch 63/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-62  with average loss of :3.126727316416511e-06
# Epoch 64/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-63  with average loss of :3.1274254743124613e-06
# Epoch 65/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-64  with average loss of :3.1333709051259938e-06
# Epoch 66/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-65  with average loss of :3.098913834832118e-06
# Epoch 67/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-66  with average loss of :3.2209969006124547e-06
# Epoch 68/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-67  with average loss of :3.438186019620396e-06
# Epoch 69/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-68  with average loss of :3.2001951423064597e-06
# Epoch 70/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-69  with average loss of :3.19494938582457e-06
# Epoch 71/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-70  with average loss of :3.2143809242117997e-06
# Epoch 72/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-71  with average loss of :3.1689121445867447e-06
# Epoch 73/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-72  with average loss of :3.0671907627082866e-06
# Epoch 74/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-73  with average loss of :3.1530269966229044e-06
# Epoch 75/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-74  with average loss of :3.1064758816920165e-06
# Epoch 76/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-75  with average loss of :3.101481512700677e-06
# Epoch 77/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-76  with average loss of :3.1180586223711752e-06
# Epoch 78/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-77  with average loss of :3.1115866822778837e-06
# Epoch 79/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-78  with average loss of :3.05164669617312e-06
# Epoch 80/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-79  with average loss of :3.091240746966105e-06
# Epoch 81/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-80  with average loss of :3.080281784030515e-06
# Epoch 82/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-81  with average loss of :2.99899998475903e-06
# Epoch 83/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-82  with average loss of :3.0277659786526546e-06
# Epoch 84/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-83  with average loss of :3.0783062542344166e-06
# Epoch 85/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-84  with average loss of :3.044687955798372e-06
# Epoch 86/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-85  with average loss of :3.039842069202268e-06
# Epoch 87/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-86  with average loss of :3.0374931901780766e-06
# Epoch 88/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-87  with average loss of :3.093017357910947e-06
# Epoch 89/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-88  with average loss of :3.0319055958399126e-06
# Epoch 90/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-89  with average loss of :3.06482366741621e-06
# Epoch 91/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-90  with average loss of :3.026906183008903e-06
# Epoch 92/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-91  with average loss of :3.0582976527337376e-06
# Epoch 93/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-92  with average loss of :3.144318637566261e-06
# Epoch 94/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-93  with average loss of :3.1240805000572567e-06
# Epoch 95/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-94  with average loss of :3.2732786862633066e-06
# Epoch 96/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-95  with average loss of :3.2745571635295727e-06
# Epoch 97/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-96  with average loss of :3.2517271250413574e-06
# Epoch 98/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-97  with average loss of :3.224001108791698e-06
# Epoch 99/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-98  with average loss of :3.2005730296878193e-06
# Epoch 100/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-99  with average loss of :3.201435898189682e-06
# Epoch 101/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-100  with average loss of :3.146670125083488e-06
# Epoch 102/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-101  with average loss of :3.124644160375569e-06
# Epoch 103/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-102  with average loss of :3.163618949818098e-06
# Epoch 104/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-103  with average loss of :3.1622629240524546e-06
# Epoch 105/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-104  with average loss of :3.120476659294301e-06
# Epoch 106/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-105  with average loss of :3.1036409258291774e-06
# Epoch 107/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-106  with average loss of :3.090782061525451e-06
# Epoch 108/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-107  with average loss of :3.1193720693149704e-06
# Epoch 109/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-108  with average loss of :2.9919783748147792e-06
# Epoch 110/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-109  with average loss of :3.0420010079786494e-06
# Epoch 111/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-110  with average loss of :3.0770321385557166e-06
# Epoch 112/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-111  with average loss of :3.0388105450561312e-06
# Epoch 113/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-112  with average loss of :3.1114704364505793e-06
# Epoch 114/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-113  with average loss of :2.992893580439758e-06
# Epoch 115/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-114  with average loss of :3.010878737489159e-06
# Epoch 116/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-115  with average loss of :3.0216052596205305e-06
# Epoch 117/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-116  with average loss of :3.045000828317391e-06
# Epoch 118/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-117  with average loss of :3.1586780187160165e-06
# Epoch 119/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-118  with average loss of :3.1774724377138056e-06
# Epoch 120/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-119  with average loss of :3.052078663825169e-06
# Epoch 121/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-120  with average loss of :3.1656578543155717e-06
# Epoch 122/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-121  with average loss of :3.129188999341233e-06
# Epoch 123/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-122  with average loss of :3.1648776274971277e-06
# Epoch 124/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-123  with average loss of :3.1760242393347264e-06
# Epoch 125/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-124  with average loss of :3.125184047614014e-06
# Epoch 126/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-125  with average loss of :3.2021541581527725e-06
# Epoch 127/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-126  with average loss of :3.182383513447311e-06
# Epoch 128/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-127  with average loss of :3.2011409850438056e-06
# Epoch 129/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-128  with average loss of :3.1333786411592785e-06
# Epoch 130/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-129  with average loss of :3.1051935991161266e-06
# Epoch 131/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-130  with average loss of :3.131112200853956e-06
# Epoch 132/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-131  with average loss of :3.122297288257057e-06
# Epoch 133/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-132  with average loss of :3.115191140619189e-06
# Epoch 134/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-133  with average loss of :3.02450482108924e-06
# Epoch 135/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-134  with average loss of :3.067676438856305e-06
# Epoch 136/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-135  with average loss of :3.030149305514544e-06
# Epoch 137/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-136  with average loss of :3.053494094256845e-06
# Epoch 138/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-137  with average loss of :3.031306205147611e-06
# Epoch 139/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-138  with average loss of :3.081217748097262e-06
# Epoch 140/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-139  with average loss of :3.0315294436365566e-06
# Epoch 141/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-140  with average loss of :3.069491664382266e-06
# Epoch 142/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-141  with average loss of :3.021129172766723e-06
# Epoch 143/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-142  with average loss of :2.95897073824438e-06
# Epoch 144/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-143  with average loss of :3.036202587392083e-06
# Epoch 145/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-144  with average loss of :3.0656928350922615e-06
# Epoch 146/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-145  with average loss of :3.0243907956656497e-06
# Epoch 147/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-146  with average loss of :3.0387082109237413e-06
# Epoch 148/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-147  with average loss of :3.124312180223501e-06
# Epoch 149/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-148  with average loss of :3.108099390090599e-06
# Epoch 150/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-149  with average loss of :3.1131430787221617e-06
# Epoch 151/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-150  with average loss of :3.0910590732324314e-06
# Epoch 152/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-151  with average loss of :3.281776975260918e-06
# Epoch 153/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-152  with average loss of :3.2472461938895398e-06
# Epoch 154/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-153  with average loss of :3.1766059757187985e-06
# Epoch 155/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-154  with average loss of :3.2878827456765285e-06
# Epoch 156/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-155  with average loss of :3.293288810370939e-06
# Epoch 157/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-156  with average loss of :3.1798587634277612e-06
# Epoch 158/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-157  with average loss of :3.1552692527959814e-06
# Epoch 159/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-158  with average loss of :3.222451124556782e-06
# Epoch 160/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-159  with average loss of :3.077967309566688e-06
# Epoch 161/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-160  with average loss of :3.1332236875394266e-06
# Epoch 162/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-161  with average loss of :3.133150242147907e-06
# Epoch 163/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-162  with average loss of :3.094017449029032e-06
# Epoch 164/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-163  with average loss of :3.046000780711808e-06
# Epoch 165/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-164  with average loss of :3.038120944672386e-06
# Epoch 166/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-165  with average loss of :3.0341925817086136e-06
# Epoch 167/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-166  with average loss of :3.0848167166724664e-06
# Epoch 168/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-167  with average loss of :3.0438009869565932e-06
# Epoch 169/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-168  with average loss of :3.006361045495496e-06
# Epoch 170/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-169  with average loss of :3.023723730115414e-06
# Epoch 171/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-170  with average loss of :3.1014662862685664e-06
# Epoch 172/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-171  with average loss of :3.021330029441613e-06
# Epoch 173/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-172  with average loss of :2.974904998456658e-06
# Epoch 174/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-173  with average loss of :3.0776274979287505e-06
# Epoch 175/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-174  with average loss of :3.093151486340607e-06
# Epoch 176/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-175  with average loss of :3.1228704768345128e-06
# Epoch 177/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-176  with average loss of :3.0748273134867234e-06
# Epoch 178/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-177  with average loss of :3.076103720074112e-06
# Epoch 179/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-178  with average loss of :3.1267423967924532e-06
# Epoch 180/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-179  with average loss of :3.1774607481896744e-06
# Epoch 181/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-180  with average loss of :3.26786491663966e-06
# Epoch 182/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-181  with average loss of :3.2144874493912043e-06
# Epoch 183/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-182  with average loss of :3.2810045661010377e-06
# Epoch 184/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-183  with average loss of :3.154794903154315e-06
# Epoch 185/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-184  with average loss of :3.127294667540832e-06
# Epoch 186/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-185  with average loss of :3.1172356608640335e-06
# Epoch 187/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-186  with average loss of :3.135744062969093e-06
# Epoch 188/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-187  with average loss of :3.1773132201749857e-06
# Epoch 189/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-188  with average loss of :3.1510227110288282e-06
# Epoch 190/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-189  with average loss of :3.1632280633803194e-06
# Epoch 191/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-190  with average loss of :3.0578873577382233e-06
# Epoch 192/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-191  with average loss of :3.1458137650234402e-06
# Epoch 193/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-192  with average loss of :3.1002086695310587e-06
# Epoch 194/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-193  with average loss of :3.158252846318888e-06
# Epoch 195/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-194  with average loss of :2.9910958813145243e-06
# Epoch 196/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-195  with average loss of :3.051559529600372e-06
# Epoch 197/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-196  with average loss of :3.0773177771359786e-06
# Epoch 198/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-197  with average loss of :3.0473377759300586e-06
# Epoch 199/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-198  with average loss of :3.078477128059935e-06
# Epoch 200/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-199  with average loss of :3.0382626646012785e-06
# Epoch 201/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-200  with average loss of :3.010387701101914e-06
# Epoch 202/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-201  with average loss of :3.0900236102029253e-06
# Epoch 203/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-202  with average loss of :3.0127507322561934e-06
# Epoch 204/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-203  with average loss of :3.0881102930503223e-06
# Epoch 205/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-204  with average loss of :3.0904143532848216e-06
# Epoch 206/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-205  with average loss of :3.092870262626425e-06
# Epoch 207/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-206  with average loss of :3.0649907308461134e-06
# Epoch 208/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-207  with average loss of :3.1771861025926067e-06
# Epoch 209/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-208  with average loss of :3.141656444863807e-06
# Epoch 210/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-209  with average loss of :3.1569676251457526e-06
# Epoch 211/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-210  with average loss of :3.1936694580186165e-06
# Epoch 212/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-211  with average loss of :3.2114087820317004e-06
# Epoch 213/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-212  with average loss of :3.2480633375119833e-06
# Epoch 214/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-213  with average loss of :3.2741856831690815e-06
# Epoch 215/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-214  with average loss of :3.1795527136759563e-06
# Epoch 216/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-215  with average loss of :3.1582371187311295e-06
# Epoch 217/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-216  with average loss of :3.148709970289618e-06
# Epoch 218/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-217  with average loss of :3.1199773274539845e-06
# Epoch 219/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-218  with average loss of :3.037823838012773e-06
# Epoch 220/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-219  with average loss of :3.073261916824307e-06
# Epoch 221/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-220  with average loss of :3.091470341371968e-06
# Epoch 222/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-221  with average loss of :3.082648229020528e-06
# Epoch 223/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-222  with average loss of :3.023493077870522e-06
# Epoch 224/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-223  with average loss of :3.0437194046922286e-06
# Epoch 225/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-224  with average loss of :3.0161810854794138e-06
# Epoch 226/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-225  with average loss of :3.1005207826605455e-06
# Epoch 227/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-226  with average loss of :3.0522165068623013e-06
# Epoch 228/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-227  with average loss of :2.998117457012254e-06
# Epoch 229/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-228  with average loss of :3.032338162456068e-06
# Epoch 230/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-229  with average loss of :3.1018360458391686e-06
# Epoch 231/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-230  with average loss of :3.060264689778278e-06
# Epoch 232/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-231  with average loss of :3.0676280446299394e-06
# Epoch 233/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-232  with average loss of :3.121707560260838e-06
# Epoch 234/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-233  with average loss of :3.0481224370796716e-06
# Epoch 235/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-234  with average loss of :3.142525784614228e-06
# Epoch 236/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-235  with average loss of :3.1863579668757456e-06
# Epoch 237/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-236  with average loss of :3.183256163951591e-06
# Epoch 238/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-237  with average loss of :3.1230726702541298e-06
# Epoch 239/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-238  with average loss of :3.196333107148001e-06
# Epoch 240/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-239  with average loss of :3.1759737711729086e-06
# Epoch 241/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-240  with average loss of :3.1895676299999805e-06
# Epoch 242/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-241  with average loss of :3.159927880826928e-06
# Epoch 243/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-242  with average loss of :3.241506270924009e-06
# Epoch 244/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-243  with average loss of :3.2192560372654478e-06
# Epoch 245/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-244  with average loss of :3.1458212134041514e-06
# Epoch 246/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-245  with average loss of :3.1281322348461656e-06
# Epoch 247/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-246  with average loss of :3.0830967615973426e-06
# Epoch 248/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-247  with average loss of :3.0409489646259643e-06
# Epoch 249/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-248  with average loss of :3.078413087177932e-06
# Epoch 250/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-249  with average loss of :3.0452349238560287e-06
# Epoch 251/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-250  with average loss of :3.0591596029689397e-06
# Epoch 252/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-251  with average loss of :3.0989096180200895e-06
# Epoch 253/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-252  with average loss of :3.1040426625552515e-06
# Epoch 254/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-253  with average loss of :3.0730308655515244e-06
# Epoch 255/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-254  with average loss of :3.0330100100855627e-06
# Epoch 256/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-255  with average loss of :3.04093303755699e-06
# Epoch 257/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-256  with average loss of :3.085161346880551e-06
# Epoch 258/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-257  with average loss of :3.0475666554259154e-06
# Epoch 259/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-258  with average loss of :3.0063448894818872e-06
# Epoch 260/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-259  with average loss of :3.0443450158238337e-06
# Epoch 261/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-260  with average loss of :3.073429100233275e-06
# Epoch 262/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-261  with average loss of :3.1169835812755373e-06
# Epoch 263/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-262  with average loss of :3.133738652124902e-06
# Epoch 264/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-263  with average loss of :3.0945431230246466e-06
# Epoch 265/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-264  with average loss of :3.216739150183752e-06
# Epoch 266/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-265  with average loss of :3.150980677530906e-06
# Epoch 267/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-266  with average loss of :3.1658119259842123e-06
# Epoch 268/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-267  with average loss of :3.2140024739144848e-06
# Epoch 269/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-268  with average loss of :3.155717128415506e-06
# Epoch 270/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-269  with average loss of :3.186666129054711e-06
# Epoch 271/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-270  with average loss of :3.174567938565788e-06
# Epoch 272/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-271  with average loss of :3.1687163154130563e-06
# Epoch 273/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-272  with average loss of :3.0998208031517334e-06
# Epoch 274/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-273  with average loss of :3.1234522286420113e-06
# Epoch 275/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-274  with average loss of :3.0567125881068145e-06
# Epoch 276/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-275  with average loss of :3.080243919109426e-06
# Epoch 277/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-276  with average loss of :3.0159017278688638e-06
# Epoch 278/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-277  with average loss of :3.0898429468449266e-06
# Epoch 279/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-278  with average loss of :3.087164599809952e-06
# Epoch 280/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-279  with average loss of :3.0744106434191355e-06
# Epoch 281/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-280  with average loss of :3.095783757436597e-06
# Epoch 282/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-281  with average loss of :2.985721833363426e-06
# Epoch 283/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-282  with average loss of :2.9911307249595394e-06
# Epoch 284/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-283  with average loss of :3.0000145581903357e-06
# Epoch 285/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-284  with average loss of :3.0857386652953883e-06
# Epoch 286/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-285  with average loss of :2.9946730433486274e-06
# Epoch 287/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-286  with average loss of :3.1068029812437873e-06
# Epoch 288/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-287  with average loss of :2.9680019045834582e-06
# Epoch 289/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-288  with average loss of :3.052161517394771e-06
# Epoch 290/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-289  with average loss of :3.010769853550019e-06
# Epoch 291/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-290  with average loss of :3.0782614913079007e-06
# Epoch 292/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-291  with average loss of :3.056801967619213e-06
# Epoch 293/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-292  with average loss of :3.104409762148566e-06
# Epoch 294/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-293  with average loss of :3.1636623344045567e-06
# Epoch 295/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-294  with average loss of :3.2261954396497033e-06
# Epoch 296/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-295  with average loss of :3.265546186519574e-06
# Epoch 297/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-296  with average loss of :3.169612779724356e-06
# Epoch 298/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-297  with average loss of :3.2538028211366654e-06
# Epoch 299/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-298  with average loss of :3.145981332581031e-06
# Epoch 300/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-299  with average loss of :3.201390898621125e-06
# Epoch 301/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-300  with average loss of :3.233871118639518e-06
# Epoch 302/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-301  with average loss of :3.229761717887476e-06
# Epoch 303/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-302  with average loss of :3.109993604225242e-06
# Epoch 304/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-303  with average loss of :3.137268648171766e-06
# Epoch 305/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-304  with average loss of :3.0989148227182177e-06
# Epoch 306/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-305  with average loss of :3.089367598543594e-06
# Epoch 307/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-306  with average loss of :3.092652939189465e-06
# Epoch 308/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-307  with average loss of :3.089310325566054e-06
# Epoch 309/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-308  with average loss of :2.97535091588465e-06
# Epoch 310/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-309  with average loss of :3.064240651750946e-06
# Epoch 311/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-310  with average loss of :3.1100151830842425e-06
# Epoch 312/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-311  with average loss of :3.0517359084104507e-06
# Epoch 313/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-312  with average loss of :3.063973047297839e-06
# Epoch 314/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-313  with average loss of :3.0471977249723794e-06
# Epoch 315/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-314  with average loss of :2.9819040192788683e-06
# Epoch 316/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-315  with average loss of :3.016089953203422e-06
# Epoch 317/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-316  with average loss of :3.050108483830139e-06
# Epoch 318/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-317  with average loss of :3.021463803580554e-06
# Epoch 319/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-318  with average loss of :3.023572533285921e-06
# Epoch 320/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-319  with average loss of :3.0526334564645836e-06
# Epoch 321/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-320  with average loss of :3.096312857219931e-06
# Epoch 322/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-321  with average loss of :3.1059042042431232e-06
# Epoch 323/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-322  with average loss of :3.1713197313130754e-06
# Epoch 324/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-323  with average loss of :3.2814201651326367e-06
# Epoch 325/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-324  with average loss of :3.2394062153387273e-06
# Epoch 326/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-325  with average loss of :3.244237933995227e-06
# Epoch 327/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-326  with average loss of :3.2492106001336098e-06
# Epoch 328/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-327  with average loss of :3.4518851470284865e-06
# Epoch 329/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-328  with average loss of :3.3320542054935628e-06
# Epoch 330/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-329  with average loss of :3.252126171510005e-06
# Epoch 331/1100:   0%|          | 0/14 [00:00<?, ?it/s]
# Finished epoch-330  with average loss of :3.1648631748070187e-06
# Epoch 332/1100:   0%|          | 0/14 [00:00<?, ?it/s]

# %% [markdown]
# # Sampling

# %%
import torchvision
import shutil
import os

device = "cuda"
def save_weights_to_google_drive():
  new_folder_path = '/content/drive/MyDrive/ConditionalDiffusionModelWeights'
  os.makedirs(new_folder_path, exist_ok=True)

  weights_source_path = "./ModelWeights/weights_epoch_75"
  optimizer_path = "./ModelWeights/epoch_75_optimizer.pt"
  scheduler_path = "./ModelWeights/scheduler.pt"

  shutil.copy(weights_source_path, new_folder_path)
  shutil.copy(optimizer_path, new_folder_path)
  shutil.copy(scheduler_path, new_folder_path)

# save_weights_to_google_drive()

pre_model = ClassConditionedUNet()

pre_model.load_state_dict(torch.load("/content/drive/MyDrive/ConditionalDiffusionModelWeights/weights_425"))
pre_model.to(device)

x = torch.randn(80, 1, 28, 28).to(device)
y = torch.tensor([[i] * 8 for i in range(10)]).flatten().to(device)

# Sampling loop
for i, t in tqdm(enumerate(noise_scheduler.timesteps)):

    # Get model pred
  with torch.no_grad():
    t.to(device)
    residual = pre_model(x, t, y)  # Again, note that we pass in our labels y

    # Update sample with step
    x = noise_scheduler.step(residual, t, x).prev_sample

# Show the results
fig, ax = plt.subplots(1, 1, figsize=(12, 12))
ax.imshow(torchvision.utils.make_grid(x.detach().cpu().clip(-1, 1), nrow=8)[0])
# Out:
# <ipython-input-6-70ef9d5f59b5>:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   pre_model.load_state_dict(torch.load("/content/drive/MyDrive/ConditionalDiffusionModelWeights/weights_425"))
# 0it [00:00, ?it/s]
